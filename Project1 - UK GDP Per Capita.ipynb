# %%
# !pip install fredapi

# %%
from fredapi import Fred
import pandas as pd
import matplotlib.pyplot as plt

#replace with acc fredapi key

fred = Fred(api_key='88ad56fee8502dd5d3634bc8cc2473a8')

#ukdata
# Changed to UK GDP per capita series ID
# Using 'NGDPPCGBQA156N' for Nominal GDP per Capita in United Kingdom
uk_gdp_per_capita = fred.get_series('PCAGDPGBA646NWDB')

print(uk_gdp_per_capita.head(10))

print(type(uk_gdp_per_capita))

df_gdp = uk_gdp_per_capita.to_frame(name='UK_GDP_per_Capita')

#visulation
print(df_gdp.head(10))

# Create the plot
df_gdp.plot(figsize=(12,6))

# Apply customizations
plt.title('UK GDP per Capita')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')
plt.grid(True, alpha=0.3)

# Save the figure before showing it
plt.savefig('uk_gdp_per_capita.png')

# Display the plot once
plt.show()
# Out:
# 1960-01-01    1397.594803
# 1961-01-01    1472.385714
# 1962-01-01    1525.775853
# 1963-01-01    1613.456884
# 1964-01-01    1748.288118
# 1965-01-01    1873.567774
# 1966-01-01    1986.747159
# 1967-01-01    2058.781882
# 1968-01-01    1951.758596
# 1969-01-01    2100.667869
# dtype: float64
# <class 'pandas.core.series.Series'>
#             UK_GDP_per_Capita
# 1960-01-01        1397.594803
# 1961-01-01        1472.385714
# 1962-01-01        1525.775853
# 1963-01-01        1613.456884
# 1964-01-01        1748.288118
# 1965-01-01        1873.567774
# 1966-01-01        1986.747159
# 1967-01-01        2058.781882
# 1968-01-01        1951.758596
# 1969-01-01        2100.667869

# %% [markdown]
# This is a simple code aimed at displaying UK GDP per capita over time, sucessfully achieved by using the FRED API key and access to its database.
